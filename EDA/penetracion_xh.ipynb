# %% [markdown]
# En el siguiente notebook, se va a trabajar con los datos con el fin de poder sacar el máximo provecho de los datos de una forma más ordenada, detectando los valores faltantes, los datos duplicados y atípicos para que no afecte de manera negativa al análisis.

# %%
# Se importan las librerías necesarias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings

# %%
# Se cargan los datos de la hoja llamada Penetracion-hogares 
df_internet_pxh = pd.read_excel('../Data/Internet.xlsx', sheet_name='Penetracion-hogares')

# %%
df_internet_pxh
# Out:
#       Año  Trimestre            Provincia  Accesos por cada 100 hogares
# 0    2024          1         Buenos Aires                     81.100000
# 1    2024          1      Capital Federal                    119.530000
# 2    2024          1            Catamarca                     68.820000
# 3    2024          1                Chaco                     46.700000
# 4    2024          1               Chubut                     84.890000
# ..    ...        ...                  ...                           ...
# 979  2014          1           Santa Cruz                     28.939093
# 980  2014          1             Santa Fe                     47.847663
# 981  2014          1  Santiago Del Estero                     16.309924
# 982  2014          1     Tierra Del Fuego                     63.965926
# 983  2014          1              Tucumán                     33.420975
#
# [984 rows x 4 columns]

# %%
# Se realiza una búsqueda de los valores faltantes
valores_faltantes = df_internet_pxh.isnull().sum()

# Muestra de los valores faltantes
valores_faltantes = valores_faltantes[valores_faltantes > 0]
valores_faltantes
# Out:
# Series([], dtype: int64)

# %%
# Verificación de registros duplicados
duplicados = df_internet_pxh.duplicated().sum()
duplicados
# Out:
# 0

# %%
# Se crea un boxplot para detectar valores atípicos

plt.figure(figsize=(12, 6))
sns.boxplot(data=df_internet_pxh, orient='h')
plt.title('Diagrama de Caja para detectar valores atípicos')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma de accesos
plt.figure(figsize=(10, 6))
sns.histplot(df_internet_pxh['Accesos por cada 100 hogares'], bins=20, kde=True)
plt.title('Distribución de Accesos por cada 100 Hogares')
plt.xlabel('Accesos por cada 100 Hogares')
plt.ylabel('Frecuencia')
plt.show()

# Boxplot para visualizar la dispersión
plt.figure(figsize=(10, 6))
sns.boxplot(x='Accesos por cada 100 hogares', data=df_internet_pxh)
plt.title('Boxplot de Accesos por cada 100 Hogares')
plt.xlabel('Accesos por cada 100 Hogares')
plt.show()

# %%
# Tendencia de accesos a lo largo del tiempo
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_internet_pxh, x='Año', y='Accesos por cada 100 hogares', hue='Trimestre')
plt.title('Tendencia de Accesos a lo Largo del Tiempo')
plt.xlabel('Año')
plt.ylabel('Accesos por cada 100 Hogares')
plt.show()

# %%
# Boxplot de accesos por provincia
plt.figure(figsize=(12, 8))
sns.boxplot(x='Provincia', y='Accesos por cada 100 hogares', data=df_internet_pxh)
plt.title('Accesos por Provincia')
plt.xticks(rotation=90)
plt.xlabel('Provincia')
plt.ylabel('Accesos por cada 100 Hogares')
plt.show()

# %%
# Tendencia de accesos a lo largo del tiempo por provincia
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_internet_pxh, x='Año', y='Accesos por cada 100 hogares', hue='Provincia')
plt.title('Tendencia de Accesos a lo Largo del Tiempo por Provincia')
plt.xlabel('Año')
plt.ylabel('Accesos por cada 100 Hogares')
plt.legend(title='Provincia')
plt.show()
